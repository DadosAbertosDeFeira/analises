# %% [markdown]
# # Dá para cortar?
#
# Antes mesmo da epidemia chegar ao município de Feira de Santana,
# a Câmara de Vereadores já era conhecida por seus gastos extravagantes.
# A casa já chegou a gastar, de uma só vez, [17.767,60 em iogurtes][1]
# e disponibilizar 60 linhas de telefone celular para uso dos vereadores ,
# apesar dos gastos [R$ 40 mil anuais com a Telemar][1].
#
# [1]: https://www.blogdovelame.com/camara-de-feira-ja-chegou-a-comprar-616-unidades-de-iogurte-de-uma-so-vez/
# [2]: https://www.blogdovelame.com/camara-de-feira-disponibiliza-60-linhas-de-telefone-celular-para-uso-dos-vereadores/
#
#
# Muitas Câmaras tem se mobilizado para cortar gastos e repassar a verba
# para que a prefeitura utilize nos esforços para conter a pandemia.
#
# Nesse texto vamos conhecer um pouco melhor as despesas da Câmara e
# o que pode ser cortado para ajudar o município na crise do COVID-19.
#
# ## As despesas da Câmara Municipal
#
# Antes, vamos entender um pouco sobre as despesas, segundo a própria Câmara:
#
# > São todos os gastos feitos pela Câmara. As Despesas são divididas em:
#
# > - Despesas correntes. Aquelas necessárias à manutenção dos serviços públicos, como as despesas com material de consumo, telefone, pessoal, serviços de terceiros, etc.
# > - Despesas de capital. São os investimentos, ou seja, gastos com novos equipamentos e obras, como construção e reforma de escolas, hospitais, postos de saúde, pavimentação, etc.
# Os registros de classificação da despesa são efetuados por meio de rotinas específicas e de forma geral podem ser assim tratadas:
#
# > - Valor Orçado (Dotação Orçamentária) - Dependem de autorização legislativa e correspondem ao valor a ser utilizado para a manutenção da Administração Pública;
# > - Valor Empenhado - Consiste na reserva da dotação orçamentária para um fim específico, devendo registrar o nome/razão social do credor, valor e descrição do que será pago;
# > - Valor Liquidado - Registra efetivamente a despesa executada. No entanto, por ocasião do encerramento do exercício, conforme as normas da Lei Federal n° 4.320/1964, as despesas empenhadas e ainda não liquidadas são inscritas em restos a pagar não processados;
# > - Valor Pago - Consiste na entrega do numerário ao credor e só pode ser efetuado após regular liquidação da despesa.
#
# Fonte: https://www.transparencia.feiradesantana.ba.leg.br/index.php?view=despesasinfo
#
# No [portal da transparência](https://www.transparencia.feiradesantana.ba.leg.br/index.php?view=despesasinfo)
# podemos verificar os gastos nas três fases: empenho, liquidação e pagamento. Cada despesa
# apresenta também as seguintes informações:
#
# ![](images/despesa.png)
#
# * Data
# * Fase
# * Credor (Empresa ou pessoa física)
# * Valor
# * Número
# * Documento (o CPF ou CNPJ da empresa ou pessoa)
# * Número do processo
# * Bem / Serviço prestado
# * Natureza
# * Função
# * Subfunção
# * Processo licitatório
# * Fonte de recurso
#
# Mas como saber qual valor pode ser gasto pelo município durante o ano?
#
# ## Lei Orçamentária
#
# O valor que o município pode gastar, bem como a receita esperada, é estabelecido
# pela Lei Orçamentária Anual (LOA). Todos os anos o município deve estabelecer um orçamento
# para o ano seguinte. Saiba mais sobre isso [aqui](https://www.politize.com.br/ppa-ldo-loa-3-siglas-que-definem-orcamento-governo/).
#
# Embora esteja publicada no diário oficial, a LOA de Feira de Santana não foi encontrada
# facilmente nos portais da transparência da prefeitura e da câmara. Você pode acessá-la
# [aqui](http://www.diariooficial.feiradesantana.ba.gov.br/atos/executivo/1JE1WJ2162019.pdf).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Baixe os dados das despesas da Câmara aqui:
#
# https://www.kaggle.com/anapaulagomes/despesas-da-cmara-municipal
#
# Descompacte o arquivo e coloque na pasta `analysis`.

# %%
despesas = pd.read_csv('expenses-11.04.2020.csv')
despesas.head()
# Out:
#                 company_or_person                  crawled_at  \
# 0           EDITORA PRINCESA LTDA  2020-04-11 10:12:39.549868
# 1      CEDRO EDITORA GRAFICA LTDA  2020-04-11 10:12:39.553791
# 2            ELEVADORES OTIS LTDA  2020-04-11 10:12:39.561768
# 3  EMPR. BRAS. DE CORREIOS E TELE  2020-04-11 10:12:39.564685
# 4  COMANDOS TERC. E SEG. ELETR. L  2020-04-11 10:12:39.572683
#
#                                         crawled_from        date  \
# 0  https://www.transparencia.feiradesantana.ba.le...  2010-01-04
# 1  https://www.transparencia.feiradesantana.ba.le...  2010-01-04
# 2  https://www.transparencia.feiradesantana.ba.le...  2010-01-04
# 3  https://www.transparencia.feiradesantana.ba.le...  2010-01-04
# 4  https://www.transparencia.feiradesantana.ba.le...  2010-01-04
#
#              document          function  \
# 0  00.725.755/0001-62  01 - LEGISLATIVA
# 1  00.597.920/0001-30  01 - LEGISLATIVA
# 2  02.973.973/0010-01  01 - LEGISLATIVA
# 3  03.402.831/3861-17  01 - LEGISLATIVA
# 4  00.046.493/0001-07  01 - LEGISLATIVA
#
#                                              group  \
# 0  Manutencao dos servicos tecnico administrativos
# 1  Manutencao dos servicos tecnico administrativos
# 2  Manutencao dos servicos tecnico administrativos
# 3  Manutencao dos servicos tecnico administrativos
# 4  Manutencao dos servicos tecnico administrativos
#
#                                         legal_status    number    phase  \
# 0  339039680000 - Serv.de Publicidade e propagand...  062/2010  empenho
# 1  339039680000 - Serv.de Publicidade e propagand...  063/2010  empenho
# 2  339039150000 - Manut.e Conserv.de Maq.e Equipa...  041/2010  empenho
# 3  339039740000 - Outros Serv. de Terc.-P. Juridi...  042/2010  empenho
# 4  339039600000 - Vigilancia Ostensiva           ...  021/2010  empenho
#
#   process_number published_at        resource subfunction  \
# 0       029/2010   2010-01-04  0000 - TESOURO  031 - ACAO
# 1       030/2010   2010-01-04  0000 - TESOURO  031 - ACAO
# 2       019/2010   2010-01-04  0000 - TESOURO  031 - ACAO
# 3       020/2010   2010-01-04  0000 - TESOURO  031 - ACAO
# 4       013/2010   2010-01-04  0000 - TESOURO  031 - ACAO
#
#                               subgroup  \
# 0     Serv.de Publicidade e propaganda
# 1     Serv.de Publicidade e propaganda
# 2  Manut.e Conserv.de Maq.e Equipament
# 3    Outros Serv. de Terc.-P. Juridica
# 4                 Vigilancia Ostensiva
#
#                                              summary type_of_process  \
# 0  IMPORTE DESTINADO PUBLICACAO DE ATOS OFICIAIS ...        DISPENSA
# 1  IMPORTE DESTINADO A PUBLICACAO DE ATOS OFICIAI...        DISPENSA
# 2  IMPORTE DESTINADO A PAGAMENTO DE SERVICO DE MA...        DISPENSA
# 3  IMPORTE DESTINADO A PAGAMENTO DE SERVICO DE CO...        DISPENSA
# 4  IMPORTE DESTINADO A PAGAMENTO                 ...        DISPENSA
#
#                  value
# 0               130.00
# 1               360.00
# 2             5,166.72
# 3            35,000.00
# 4             2,260.00

# %%
columns = ['crawled_at', 'crawled_from', 'function', 'published_at', 'resource', 'subfunction']
despesas.drop(columns, inplace=True, axis=1)

despesas["date"] = pd.to_datetime(despesas["date"])
despesas = despesas[despesas["date"].isin(pd.date_range("2019-01-01", "2019-12-31"))]
despesas['month'] = despesas['date'].apply(lambda x : x.month)

despesas = despesas.sort_values('date', ascending=False)
despesas.head()
# Out:
#                     company_or_person       date            document  \
# 34863           FUNCIONARIOS EFETIVOS 2019-12-27  14.488.415/0001-60
# 34862  FUNCIONARIOS CARGOS EM COMISSA 2019-12-27  14.488.415/0001-60
# 34861         CAIXA ECONOMICA FEDERAL 2019-12-27  00.360.305/1611-16
# 34899                  EMPRESTIMO CEF 2019-12-27  14.488.415/0001-60
# 34898                I.R.R.F. - FOLHA 2019-12-27  14.488.415/0001-60
#
#                                                  group  \
# 34863              Administracao de pessoal e encargos
# 34862              Administracao de pessoal e encargos
# 34861  Manutencao dos servicos tecnico administrativos
# 34899                                              NaN
# 34898                                              NaN
#
#                                             legal_status    number  \
# 34863  319011010000 - V.Vant.Fixas P.Civil(Ve.Base Fo...  01814-19
# 34862  319011010000 - V.Vant.Fixas P.Civil(Ve.Base Fo...  01813-19
# 34861  339039999300000000 - Serviços Bancários       ...  19000581
# 34899                                                NaN  01816-19
# 34898                                                NaN  01815-19
#
#             phase process_number                             subgroup  \
# 34863  liquidacao            NaN  V.Vant.Fixas P.Civil(Ve.Base Folha)
# 34862  liquidacao            NaN  V.Vant.Fixas P.Civil(Ve.Base Folha)
# 34861     empenho            NaN                   Serviços Bancários
# 34899   pagamento            NaN                                  NaN
# 34898   pagamento            NaN                                  NaN
#
#                                                  summary type_of_process  \
# 34863  REF. A VENCIMENTOS DOS SERVIDORES EFETIVOS, FO...          ISENTO
# 34862  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...          ISENTO
# 34861     ANULACAO PARCIAL DO EMPENHO DE NUMERO 19000533          ISENTO
# 34899         PAGAMENTO EXTRA-ORCAMENTARIO NUMERO:000403             NaN
# 34898         PAGAMENTO EXTRA-ORCAMENTARIO NUMERO:000402             NaN
#
#                      value  month
# 34863            39,404.46     12
# 34862            18,784.12     12
# 34861              -328.89     12
# 34899            37,753.71     12
# 34898             2,076.69     12

# %%
despesas.shape
# Out:
# (3709, 13)

# %%
despesas['value'].plot(kind='hist')

# %% [markdown]
# ## Análises por classificação das despesas
#
# > O plano de contas da despesa orçamentária da Câmara está correto, pois segue ao estabelecido pelo TCM-BA, conforme Ato nº 456/2019. O código 33903005 se refere à Material de processamento de dados. Importante lembrar que a STN determina os elementos de despesa, de acordo com a Portaria Interministerial nº 163/2001, mas os desdobramentos da despesa (subelementos) são determinados pelo TCM BA. Segue em anexo o ato normativo com os códigos de despesa.
#
# ESPECIFICAÇÃO DE DESPESA 2020
#
# https://www.tcm.ba.gov.br/contabilidade-municipal/
#
# Faça o download do arquivo `.csv` do natureza das despesas [aqui](https://gist.githubusercontent.com/anapaulagomes/379525586f941a1183aa448dad282f90/raw/378f01c23f0ead542a88fde6274b12ba82b84f8e/especificacao-despesas-tcm-bahia.csv) e coloque na pasta `analysis`.
#
#
# ### Categoria econômica
#
#
# CATEGORIA ECONÔMICA: a despesa orçamentária, assim como a receita orçamentária, é classificada em duas categorias econômicas:
#
# 3-DESPESAS CORRENTES: classificam-se nesta categoria todas as despesas que não contribuem, diretamente, para a formação ou aquisição de um bem de capital.
#
# 4 -DESPESAS  DE  CAPITAL: classificam-se  nesta  categoria  aquelas  despesas  que contribuem, diretamente, para a formação ou aquisição de um bem de capital

# %%
despesas["legal_status"].unique()
# Out:
# array(['319011010000 - V.Vant.Fixas P.Civil(Ve.Base Folha) 2001 - Administracao de pessoal e encargos',
#        '339039999300000000 - Serviços Bancários                                             2002 - Manutencao dos servicos tecnico administrativos',
#        nan,
#        '339039999600 - Manutenção e conservação de máquinas2002 - Manutencao dos servicos tecnico administrativos',
#        '339039999300 - Serviços Bancários                  2002 - Manutencao dos servicos tecnico administrativos',
#        '339047000000 - Obrigacoes Trib. e Contributivas    2002 - Manutencao dos servicos tecnico administrativos',
#        '339039930000 - Serviços Bancários                  2002 - Manutencao dos servicos tecnico administrativos',
#        '339039940000 - Seguros em Geral                    2002 - Manutencao dos servicos tecnico administrativos',
#        '319113020000 - Cont.p/Reg.Proprio Prev.ser.RPPS    2001 - Administracao de pessoal e encargos',
#        '339039010000 - Publicidades e Propaganda           2002 - Manutencao dos servicos tecnico administrativos',
#        '339039999900 - Outros Serv.Terceiros - P. Juridica 2002 - Manutencao dos servicos tecnico administrativos',
#        '339030060000 - Material P/manuntençao de Veiculos  2002 - Manutencao dos servicos tecnico administrativos',
#        '319013010000000000 - Cont.p/Reg.Geral Prev.INSS                                     2001 - Administracao de pessoal e encargos',
#        '319011010000000000 - V.Vant.Fixas P.Civil(Ve.Base Folha)                            2001 - Administracao de pessoal e encargos',
#        '319013010000000000 - Cont.p/Reg.Geral Prev.INSS                                     2003 - Administracao da acao legislativa',
#        '339049000000000000 - Auxilio - Transporte                                           2002 - Manutencao dos servicos tecnico administrativos',
#        '339047000000000000 - Obrigacoes Trib. e Contributivas                               2002 - Manutencao dos servicos tecnico administrativos',
#        '339039992500 - Vale refeição/vale alimentação      2002 - Manutencao dos servicos tecnico administrativos',
#        '339039090000 - Serviços de Telefonia               2002 - Manutencao dos servicos tecnico administrativos',
#        '339039090000000000 - Serviços de Telefonia                                          2002 - Manutencao dos servicos tecnico administrativos',
#        '339039998900 - Outros Serv.Terceiros - P. Juridica 2002 - Manutencao dos servicos tecnico administrativos',
#        '319113020000 - Cont.p/Reg.Proprio Prev.ser.RPPS    2003 - Administracao da acao legislativa',
#        '319013010000 - Cont.p/Reg.Geral Prev.INSS          2001 - Administracao de pessoal e encargos',
#        '339039992400 - Assinaturas de periódicos e pagament2002 - Manutencao dos servicos tecnico administrativos',
#        '339040000000 - Servicos de Tecnlogia da Informacao 2002 - Manutencao dos servicos tecnico administrativos',
#        '339033010000 - Despesas com passagem Aérea         2002 - Manutencao dos servicos tecnico administrativos',
#        '319013010000 - Cont.p/Reg.Geral Prev.INSS          2003 - Administracao da acao legislativa',
#        '339039010000000000 - Publicidades e Propaganda                                      2002 - Manutencao dos servicos tecnico administrativos',
#        '319113020000000000 - Cont.p/Reg.Proprio Prev.ser.RPPS                               2003 - Administracao da acao legislativa',
#        '339039999900000000 - Outros Serv.Terceiros - P. Juridica - Demais serviços          2002 - Manutencao dos servicos tecnico administrativos',
#        '339036999900 - Outros Serv.de Terceiros-P. Fisica  2002 - Manutencao dos servicos tecnico administrativos',
#        '339049000000 - Auxilio - Transporte                2002 - Manutencao dos servicos tecnico administrativos',
#        '319011010000 - V.Vant.Fixas P.Civil(Ve.Base Folha) 2003 - Administracao da acao legislativa',
#        '339036030000 - Estagiários e Monitores             2002 - Manutencao dos servicos tecnico administrativos',
#        '339030999900 - Materiais de Consumo - Outros       2002 - Manutencao dos servicos tecnico administrativos',
#        '339030020000 - Combustíveis e Lubrificantes        2002 - Manutencao dos servicos tecnico administrativos',
#        '339034019900 - Out.Serv.de Tercerizaçao-P.Jurídica 2002 - Manutencao dos servicos tecnico administrativos',
#        '339034010100 - Out.Serv.de Tercerizaçao-P.Jurídica 2002 - Manutencao dos servicos tecnico administrativos',
#        '339039110000 - Serviços de Fornecimnto de Agua     2002 - Manutencao dos servicos tecnico administrativos',
#        '339014000000 - Diarias-Civil                       2001 - Administracao de pessoal e encargos',
#        '339039940000000000 - Seguros em Geral                                               2002 - Manutencao dos servicos tecnico administrativos',
#        '339014000000000000 - Diarias-Civil                                                  2001 - Administracao de pessoal e encargos',
#        '339040000000000000 - Servicos de Tecnlogia da Informacao e Comunicação              2002 - Manutencao dos servicos tecnico administrativos',
#        '319113020000000000 - Cont.p/Reg.Proprio Prev.ser.RPPS                               2001 - Administracao de pessoal e encargos',
#        '339030030000 - Material de Escritório/Mat.de Exp.  2002 - Manutencao dos servicos tecnico administrativos',
#        '339034010100000000 - Out.Serv.de Tercerizaçao-P.Jurídica - Cooperativas de serviç   2002 - Manutencao dos servicos tecnico administrativos',
#        '339036030000000000 - Estagiários e Monitores                                        2002 - Manutencao dos servicos tecnico administrativos',
#        '339030060000000000 - Material P/manuntençao de Veiculos                             2002 - Manutencao dos servicos tecnico administrativos',
#        '339030020000000000 - Combustíveis e Lubrificantes                                   2002 - Manutencao dos servicos tecnico administrativos',
#        '469171250000 - PARCELAMENTO IPFS CAMARA            2002 - Manutencao dos servicos tecnico administrativos',
#        '329021000000 - Juros s/Divida por Contrato         2002 - Manutencao dos servicos tecnico administrativos',
#        '339030120000 - Gênero Alimentícios - Outros        2002 - Manutencao dos servicos tecnico administrativos',
#        '339039998900000000 - Outros Serv.Terceiros - P. Juridica - Transporte Escolar       2002 - Manutencao dos servicos tecnico administrativos',
#        '329021000000000000 - Juros s/Divida por Contrato                                    2002 - Manutencao dos servicos tecnico administrativos',
#        '469171250000000000 - PARCELAMENTO IPFS CAMARA                                       2002 - Manutencao dos servicos tecnico administrativos',
#        '449052069900000000 - Equip. masterial Perm. Diversos                                2002 - Manutencao dos servicos tecnico administrativos',
#        '339030030000000000 - Material de Escritório/Mat.de Exp.                             2002 - Manutencao dos servicos tecnico administrativos',
#        '339030999900000000 - Materiais de Consumo - Outros                                  2002 - Manutencao dos servicos tecnico administrativos',
#        '339030080000000000 - Material P/Manuntençao Bens Imóveis                            2002 - Manutencao dos servicos tecnico administrativos',
#        '319011010000000000 - V.Vant.Fixas P.Civil(Ve.Base Folha)                            2003 - Administracao da acao legislativa',
#        '339030991800 - Materiais de Consumo - materiais de 2002 - Manutencao dos servicos tecnico administrativos',
#        '339030991800000000 - Materiais de Consumo - materiais de limpeza e produtos de hi   2002 - Manutencao dos servicos tecnico administrativos',
#        '339039070000000000 - Serviços Gráficos                                              2002 - Manutencao dos servicos tecnico administrativos',
#        '339039992500000000 - Vale refeição/vale alimentação                                 2002 - Manutencao dos servicos tecnico administrativos',
#        '339030120000000000 - Gênero Alimentícios - Outros                                   2002 - Manutencao dos servicos tecnico administrativos',
#        '339033010000000000 - Despesas com passagem Aérea                                    2002 - Manutencao dos servicos tecnico administrativos',
#        '339039110000000000 - Serviços de Fornecimnto de Agua                                2002 - Manutencao dos servicos tecnico administrativos',
#        '339030080000 - Material P/Manuntençao Bens Imóveis 2002 - Manutencao dos servicos tecnico administrativos',
#        '339039930000000000 - Serviços Bancários                                             2002 - Manutencao dos servicos tecnico administrativos',
#        '449039990000000000 - Outros Servicos Terceiro P. Juridica                           2002 - Manutencao dos servicos tecnico administrativos',
#        '339039999600000000 - Manutenção e conservação de máquinas e equipamentos            2002 - Manutencao dos servicos tecnico administrativos',
#        '339039999400000000 - Seguros em Geral                                               2002 - Manutencao dos servicos tecnico administrativos',
#        '339034019900000000 - Out.Serv.de Tercerizaçao-P.Jurídica - Demais serviços          2002 - Manutencao dos servicos tecnico administrativos',
#        '339033020000000000 - Despesas com passagem Terrestre                                2002 - Manutencao dos servicos tecnico administrativos',
#        '339039070000 - Serviços Gráficos                   2002 - Manutencao dos servicos tecnico administrativos',
#        '449052069900 - Equip. masterial Perm. Diversos     2002 - Manutencao dos servicos tecnico administrativos',
#        '339036080000 - Servicos Prestados por Profissonais 2002 - Manutencao dos servicos tecnico administrativos',
#        '339039992400000000 - Assinaturas de periódicos e pagamento de anuidades ou mensal   2002 - Manutencao dos servicos tecnico administrativos',
#        '339036999900000000 - Outros Serv.de Terceiros-P. Fisica                             2002 - Manutencao dos servicos tecnico administrativos',
#        '339036080000000000 - Servicos Prestados por Profissonais Tec. em Engenharia/Arqui   2002 - Manutencao dos servicos tecnico administrativos',
#        '449052010000 - Equi.de Processamentos de Dados     2002 - Manutencao dos servicos tecnico administrativos',
#        '339030090000 - Material P/Manunt. Máquinas e Embar 2002 - Manutencao dos servicos tecnico administrativos',
#        '339030090000000000 - Material P/Manunt. Máquinas e Embar                            2002 - Manutencao dos servicos tecnico administrativos',
#        '449052040000 - Bens Moveis- Moveis e Utensilios    2002 - Manutencao dos servicos tecnico administrativos',
#        '339030010000 - Suprimentos de Informática          2002 - Manutencao dos servicos tecnico administrativos',
#        '339030010000000000 - Suprimentos de Informática                                     2002 - Manutencao dos servicos tecnico administrativos',
#        '449052010000000000 - Equi.de Processamentos de Dados                                2002 - Manutencao dos servicos tecnico administrativos',
#        '449052040000000000 - Bens Moveis- Moveis e Utensilios                               2002 - Manutencao dos servicos tecnico administrativos',
#        '449052020000 - Bens Moveis- Veiculos e Embarcaçoes 2002 - Manutencao dos servicos tecnico administrativos',
#        '339039999400 - Seguros em Geral                    2002 - Manutencao dos servicos tecnico administrativos',
#        '339030991900 - Materiais de Consumo - uniformes e f2002 - Manutencao dos servicos tecnico administrativos',
#        '449052020000000000 - Bens Moveis- Veiculos e Embarcaçoes                            2002 - Manutencao dos servicos tecnico administrativos',
#        '339036990900000000 - Limpeza e Conservação                                          2002 - Manutencao dos servicos tecnico administrativos',
#        '339030991900000000 - Materiais de Consumo - uniformes e fardamentos                 2002 - Manutencao dos servicos tecnico administrativos',
#        '339039120000 - Serviços de Cópias de Encardenaçoes 2002 - Manutencao dos servicos tecnico administrativos',
#        '339033020000 - Despesas com passagem Terrestre     2002 - Manutencao dos servicos tecnico administrativos',
#        '339030050000000000 - Material de Processamentos de Dados                            2002 - Manutencao dos servicos tecnico administrativos',
#        '449039990000 - Outros Servicos Terceiro P. Juridica2002 - Manutencao dos servicos tecnico administrativos',
#        '339030992000 - Materiais de Consumo - material para2002 - Manutencao dos servicos tecnico administrativos',
#        '339030992000000000 - Materiais de Consumo - material para comunicações              2002 - Manutencao dos servicos tecnico administrativos',
#        '339039120000000000 - Serviços de Cópias de Encardenaçoes                            2002 - Manutencao dos servicos tecnico administrativos',
#        '339039150000 - Locaçao de Software                 2002 - Manutencao dos servicos tecnico administrativos',
#        '339030991300 - Materiais de Consumo - gás e outros 2002 - Manutencao dos servicos tecnico administrativos',
#        '339039999100000000 - Outros Serv.Terceiros - P. Juridica - Serviços gerais e adm    2002 - Manutencao dos servicos tecnico administrativos',
#        '339039150000000000 - Locaçao de Software                                            2002 - Manutencao dos servicos tecnico administrativos',
#        '339030991300000000 - Materiais de Consumo - gás e outros materiais engarrafados     2002 - Manutencao dos servicos tecnico administrativos',
#        '449039150000000000 - Locacao de Software                                            2002 - Manutencao dos servicos tecnico administrativos'],
#       dtype=object)

# %%
classificacao = pd.read_csv(
    'especificacao-despesas-tcm-bahia.csv',
    dtype={'Codigo': str, 'Descricao': str, 'Codigo Superior': str}
)
classificacao
# Out:
#         Codigo                                          Descricao  \
# 0     30000000                                 Despesas Correntes
# 1     31000000                         Pessoal e Encargos Sociais
# 2     31300000     Transferências a Estados e ao Distrito Federal
# 3     31301100      Vencimentos e Vantagens Fixas - Pessoal Civil
# 4     31301101  Vencimento e vantagens fixas Pessoal Civil (Ve...
# ...        ...                                                ...
# 2479  77999999                       Reserva Orçamentária do RPPS
# 2480  88880000                      Recursos Provenientes de Veto
# 2481  88888800                      Recursos Provenientes de Veto
# 2482  99999900                                           Reservas
# 2483  99999999                            Reserva de Contingência
#
#      Codigo Superior
# 0                  0
# 1           30000000
# 2           31000000
# 3           31300000
# 4           31301100
# ...              ...
# 2479        77999900
# 2480               0
# 2481        88880000
# 2482               0
# 2483        99999900
#
# [2484 rows x 3 columns]

# %%
despesas['classificacao'] = despesas['legal_status'].str.extract('(\d{8})')

despesas_com_classificacao = despesas.merge(classificacao, left_on=['classificacao'], right_on=['Codigo'], how='left')
despesas_com_classificacao
# Out:
#                    company_or_person       date            document  \
# 0              FUNCIONARIOS EFETIVOS 2019-12-27  14.488.415/0001-60
# 1     FUNCIONARIOS CARGOS EM COMISSA 2019-12-27  14.488.415/0001-60
# 2            CAIXA ECONOMICA FEDERAL 2019-12-27  00.360.305/1611-16
# 3                     EMPRESTIMO CEF 2019-12-27  14.488.415/0001-60
# 4                   I.R.R.F. - FOLHA 2019-12-27  14.488.415/0001-60
# ...                              ...        ...                 ...
# 3704    MARCIO GONÇALVES DA SILVA ME 2019-01-02  11.313.206/0001-98
# 3705             S MAGALHÃES BARRETO 2019-01-02  17.191.018/0001-10
# 3706  MF COMUNICACAO E IMPRESSAO LTD 2019-01-02  04.766.784/0001-14
# 3707     REDE GERAL SERVIÇOS LTDA ME 2019-01-02  08.241.186/0001-82
# 3708     PARQUE PUBLICITÁRIO LTDA ME 2019-01-02  00.381.224/0001-90
#
#                                                 group  \
# 0                 Administracao de pessoal e encargos
# 1                 Administracao de pessoal e encargos
# 2     Manutencao dos servicos tecnico administrativos
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 3704  Manutencao dos servicos tecnico administrativos
# 3705  Manutencao dos servicos tecnico administrativos
# 3706  Manutencao dos servicos tecnico administrativos
# 3707  Manutencao dos servicos tecnico administrativos
# 3708  Manutencao dos servicos tecnico administrativos
#
#                                            legal_status    number       phase  \
# 0     319011010000 - V.Vant.Fixas P.Civil(Ve.Base Fo...  01814-19  liquidacao
# 1     319011010000 - V.Vant.Fixas P.Civil(Ve.Base Fo...  01813-19  liquidacao
# 2     339039999300000000 - Serviços Bancários       ...  19000581     empenho
# 3                                                   NaN  01816-19   pagamento
# 4                                                   NaN  01815-19   pagamento
# ...                                                 ...       ...         ...
# 3704  339039999900000000 - Outros Serv.Terceiros - P...  19000044     empenho
# 3705  339039999900000000 - Outros Serv.Terceiros - P...  19000045     empenho
# 3706  339039999900000000 - Outros Serv.Terceiros - P...  19000049     empenho
# 3707  339039999900000000 - Outros Serv.Terceiros - P...  19000017     empenho
# 3708  339039999900000000 - Outros Serv.Terceiros - P...  19000051     empenho
#
#      process_number                                           subgroup  \
# 0               NaN                V.Vant.Fixas P.Civil(Ve.Base Folha)
# 1               NaN                V.Vant.Fixas P.Civil(Ve.Base Folha)
# 2               NaN                                 Serviços Bancários
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# ...             ...                                                ...
# 3704        02/2018  Outros Serv.Terceiros - P. Juridica - Demais s...
# 3705        01/2018  Outros Serv.Terceiros - P. Juridica - Demais s...
# 3706        05/2018  Outros Serv.Terceiros - P. Juridica - Demais s...
# 3707       012/2017  Outros Serv.Terceiros - P. Juridica - Demais s...
# 3708        06/2018  Outros Serv.Terceiros - P. Juridica - Demais s...
#
#                                                 summary  type_of_process  \
# 0     REF. A VENCIMENTOS DOS SERVIDORES EFETIVOS, FO...           ISENTO
# 1     REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...           ISENTO
# 2        ANULACAO PARCIAL DO EMPENHO DE NUMERO 19000533           ISENTO
# 3            PAGAMENTO EXTRA-ORCAMENTARIO NUMERO:000403              NaN
# 4            PAGAMENTO EXTRA-ORCAMENTARIO NUMERO:000402              NaN
# ...                                                 ...              ...
# 3704  IMPORTE DESTINADO A PAGAMENTO DE DESPESAS COM ...           PREGAO
# 3705  IMPORTE DESTINADO A PAGAMENTO DE DESPESAS COM ...           PREGAO
# 3706  IMPOSTE DESTINADO A PAGAMENTO DE DESPESAS COM ...  INEXIGIBILIDADE
# 3707  IMPORTE DESTINADO A PAGAMENTO DE DESPESA COM T...           PREGAO
# 3708  IMPORTE DESTINADO A PAGAMENTO DE DESPESAS COM ...  INEXIGIBILIDADE
#
#                     value  month classificacao    Codigo  \
# 0               39,404.46     12      31901101  31901101
# 1               18,784.12     12      31901101  31901101
# 2                 -328.89     12      33903999  33903999
# 3               37,753.71     12           NaN       NaN
# 4                2,076.69     12           NaN       NaN
# ...                   ...    ...           ...       ...
# 3704            10,000.00      1      33903999  33903999
# 3705            10,000.00      1      33903999  33903999
# 3706             2,340.00      1      33903999  33903999
# 3707           104,800.00      1      33903999  33903999
# 3708             1,120.00      1      33903999  33903999
#
#                                               Descricao Codigo Superior
# 0     Vencimento e vantagens fixas Pessoal Civil (Ve...        31901100
# 1     Vencimento e vantagens fixas Pessoal Civil (Ve...        31901100
# 2        Outros Serviços de Terceiros - Pessoa Jurídica        33903900
# 3                                                   NaN             NaN
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 3704     Outros Serviços de Terceiros - Pessoa Jurídica        33903900
# 3705     Outros Serviços de Terceiros - Pessoa Jurídica        33903900
# 3706     Outros Serviços de Terceiros - Pessoa Jurídica        33903900
# 3707     Outros Serviços de Terceiros - Pessoa Jurídica        33903900
# 3708     Outros Serviços de Terceiros - Pessoa Jurídica        33903900
#
# [3709 rows x 17 columns]

# %%
despesas.shape, despesas_com_classificacao.shape
# Out:
# ((3709, 14), (3709, 17))

# %% [markdown]
# 3 Despesas Correntes
# 4 Despesas de Capital

# %% [markdown]
# ### Com o que a Câmara anda gastando?
#
# Agora que já sabemos as informações que temos e onde encontrá-las,
# vamos dar uma olhadinha nos gastos da casa no último ano.

# %% [markdown]
# O que são esses picos?
#
# * Dia 01 de Janeiro é um feriado nacional mas, em 2020, a Câmara registrou um único pagamento a Feira Cópias
# * Janeiro registrou atividade nos pagamentos durante apenas 4 dias

# %%
import seaborn as sns
sns.set_style("whitegrid")

# %%
despesas_com_classificacao.groupby(
    ['subgroup', 'Descricao', 'Codigo']
).size().reset_index().rename(columns={0: 'count'}).sort_values('count', ascending=False)
# Out:
#                                              subgroup  \
# 9                                       Diarias-Civil
# 35                Outros Serv.Terceiros - P. Juridica
# 53                V.Vant.Fixas P.Civil(Ve.Base Folha)
# 36  Outros Serv.Terceiros - P. Juridica - Demais s...
# 41                          Publicidades e Propaganda
# 6                    Cont.p/Reg.Proprio Prev.ser.RPPS
# 51                              Serviços de Telefonia
# 19                      Materiais de Consumo - Outros
# 45                Servicos de Tecnlogia da Informacao
# 1                                Auxilio - Transporte
# 5                          Cont.p/Reg.Geral Prev.INSS
# 12                            Estagiários e Monitores
# 54                     Vale refeição/vale alimentação
# 13                       Gênero Alimentícios - Outros
# 28                 Material P/manuntençao de Veiculos
# 4                        Combustíveis e Lubrificantes
# 39                 Outros Serv.de Terceiros-P. Fisica
# 32                Out.Serv.de Tercerizaçao-P.Jurídica
# 7                         Despesas com passagem Aérea
# 14                        Juros s/Divida por Contrato
# 31                   Obrigacoes Trib. e Contributivas
# 29                 Material de Escritório/Mat.de Exp.
# 50                    Serviços de Fornecimnto de Agua
# 11                    Equip. masterial Perm. Diversos
# 46  Servicos de Tecnlogia da Informacao e Comunicação
# 52                         Suprimentos de Informática
# 48                                  Serviços Gráficos
# 49                Serviços de Cópias de Encardenaçoes
# 27                Material P/Manuntençao Bens Imóveis
# 26                Material P/Manunt. Máquinas e Embar
# 10                    Equi.de Processamentos de Dados
# 18  Manutenção e conservação de máquinas e equipam...
# 34  Out.Serv.de Tercerizaçao-P.Jurídica - Demais s...
# 22                Materiais de Consumo - materiais de
# 47                                 Serviços Bancários
# 23  Materiais de Consumo - materiais de limpeza e ...
# 8                     Despesas com passagem Terrestre
# 42                                   Seguros em Geral
# 0   Assinaturas de periódicos e pagamento de anuid...
# 15                              Limpeza e Conservação
# 2                    Bens Moveis- Moveis e Utensilios
# 3                 Bens Moveis- Veiculos e Embarcaçoes
# 17                                Locaçao de Software
# 43                Servicos Prestados por Profissonais
# 20                Materiais de Consumo - gás e outros
# 40               Outros Servicos Terceiro P. Juridica
# 44  Servicos Prestados por Profissonais Tec. em En...
# 37  Outros Serv.Terceiros - P. Juridica - Serviços...
# 21  Materiais de Consumo - gás e outros materiais ...
# 33  Out.Serv.de Tercerizaçao-P.Jurídica - Cooperat...
# 16                                Locacao de Software
# 30                Material de Processamentos de Dados
# 24  Materiais de Consumo - material para comunicações
# 25     Materiais de Consumo - uniformes e fardamentos
# 38  Outros Serv.Terceiros - P. Juridica - Transpor...
#
#                                             Descricao    Codigo  count
# 9                                     Diárias – Civil  33901400    669
# 35     Outros Serviços de Terceiros - Pessoa Jurídica  33903999    394
# 53  Vencimento e vantagens fixas Pessoal Civil (Ve...  31901101    278
# 36     Outros Serviços de Terceiros - Pessoa Jurídica  33903999    162
# 41                           Publicidade e Propaganda  33903901    141
# 6   Contribuição para o Regime Próprio de Previdên...  31911302    134
# 51                              Serviços de Telefonia  33903909    123
# 19                       Material de Consumo – Outros  33903099    119
# 45  Serviços de Tecnologia da Informação e Comunic...  33904000     98
# 1                                  Auxílio-Transporte  33904900     93
# 5   Contribuição para o Regime Geral de Previdênci...  31901301     91
# 12                            Estagiários e Monitores  33903603     63
# 54     Outros Serviços de Terceiros - Pessoa Jurídica  33903999     43
# 13                      Gêneros Alimentícios – Outros  33903012     42
# 28               Material para Manutenção de Veículos  33903006     36
# 4                        Combustíveis e Lubrificantes  33903002     35
# 39       Outros Serviços de Terceiros - Pessoa Física  33903699     34
# 32  Outros Despesas de Pessoal – Terceirização – P...  33903401     32
# 7                                    Passagens Aéreas  33903301     31
# 14                  Juros sobre a Dívida por Contrato  32902100     31
# 31             Obrigações Tributárias e Contributivas  33904700     30
# 29                 Material de Escritório, Expediente  33903003     27
# 50                   Serviços de Fornecimento de Água  33903911     26
# 11    Equipamentos e Materiais Permanentes – Diversos  44905206     20
# 46  Serviços de Tecnologia da Informação e Comunic...  33904000     15
# 52                         Suprimentos de Informática  33903001     15
# 48                                  Serviços Gráficos  33903907     11
# 49                 Serviços de Cópias e Encadernações  33903912     10
# 27           Material para Manutenção de Bens Imóveis  33903008     10
# 26  Material para Manutenção de Máquinas e Embarca...  33903009      9
# 10             Equipamentos de Processamento de Dados  44905201      9
# 18     Outros Serviços de Terceiros - Pessoa Jurídica  33903999      8
# 34  Outros Despesas de Pessoal – Terceirização – P...  33903401      8
# 22                       Material de Consumo – Outros  33903099      8
# 47     Outros Serviços de Terceiros - Pessoa Jurídica  33903999      6
# 23                       Material de Consumo – Outros  33903099      6
# 8                                Passagens Terrestres  33903302      4
# 42     Outros Serviços de Terceiros - Pessoa Jurídica  33903999      4
# 0      Outros Serviços de Terceiros - Pessoa Jurídica  33903999      4
# 15       Outros Serviços de Terceiros - Pessoa Física  33903699      3
# 2                   Bens Móveis – Móveis e Utensílios  44905204      3
# 3                Bens Móveis – Veículos e Embarcações  44905202      3
# 17                                Locação de Software  33903915      3
# 43  Serviços prestados por profissionais técnicos ...  33903608      2
# 20                       Material de Consumo – Outros  33903099      2
# 40     Outros Serviços de Terceiros - Pessoa Jurídica  44903999      2
# 44  Serviços prestados por profissionais técnicos ...  33903608      1
# 37     Outros Serviços de Terceiros - Pessoa Jurídica  33903999      1
# 21                       Material de Consumo – Outros  33903099      1
# 33  Outros Despesas de Pessoal – Terceirização – P...  33903401      1
# 16                                Locação de Software  44903915      1
# 30                 Material de Processamento de Dados  33903005      1
# 24                       Material de Consumo – Outros  33903099      1
# 25                       Material de Consumo – Outros  33903099      1
# 38     Outros Serviços de Terceiros - Pessoa Jurídica  33903999      1

# %%
despesas_com_classificacao.groupby(
    ['subgroup', 'Descricao', 'Codigo'], as_index=False
)['value'].sum().sort_values(by='value', ascending=False)
# Out:
#                                              subgroup  \
# 53                V.Vant.Fixas P.Civil(Ve.Base Folha)
# 5                          Cont.p/Reg.Geral Prev.INSS
# 32                Out.Serv.de Tercerizaçao-P.Jurídica
# 6                    Cont.p/Reg.Proprio Prev.ser.RPPS
# 54                     Vale refeição/vale alimentação
# 34  Out.Serv.de Tercerizaçao-P.Jurídica - Demais s...
# 35                Outros Serv.Terceiros - P. Juridica
# 36  Outros Serv.Terceiros - P. Juridica - Demais s...
# 12                            Estagiários e Monitores
# 41                          Publicidades e Propaganda
# 1                                Auxilio - Transporte
# 3                 Bens Moveis- Veiculos e Embarcaçoes
# 9                                       Diarias-Civil
# 4                        Combustíveis e Lubrificantes
# 51                              Serviços de Telefonia
# 45                Servicos de Tecnlogia da Informacao
# 46  Servicos de Tecnlogia da Informacao e Comunicação
# 14                        Juros s/Divida por Contrato
# 19                      Materiais de Consumo - Outros
# 10                    Equi.de Processamentos de Dados
# 7                         Despesas com passagem Aérea
# 11                    Equip. masterial Perm. Diversos
# 52                         Suprimentos de Informática
# 29                 Material de Escritório/Mat.de Exp.
# 28                 Material P/manuntençao de Veiculos
# 13                       Gênero Alimentícios - Outros
# 49                Serviços de Cópias de Encardenaçoes
# 27                Material P/Manuntençao Bens Imóveis
# 42                                   Seguros em Geral
# 50                    Serviços de Fornecimnto de Agua
# 48                                  Serviços Gráficos
# 43                Servicos Prestados por Profissonais
# 39                 Outros Serv.de Terceiros-P. Fisica
# 22                Materiais de Consumo - materiais de
# 17                                Locaçao de Software
# 23  Materiais de Consumo - materiais de limpeza e ...
# 0   Assinaturas de periódicos e pagamento de anuid...
# 18  Manutenção e conservação de máquinas e equipam...
# 31                   Obrigacoes Trib. e Contributivas
# 44  Servicos Prestados por Profissonais Tec. em En...
# 26                Material P/Manunt. Máquinas e Embar
# 2                    Bens Moveis- Moveis e Utensilios
# 30                Material de Processamentos de Dados
# 15                              Limpeza e Conservação
# 25     Materiais de Consumo - uniformes e fardamentos
# 20                Materiais de Consumo - gás e outros
# 47                                 Serviços Bancários
# 21  Materiais de Consumo - gás e outros materiais ...
# 16                                Locacao de Software
# 8                     Despesas com passagem Terrestre
# 38  Outros Serv.Terceiros - P. Juridica - Transpor...
# 40               Outros Servicos Terceiro P. Juridica
# 24  Materiais de Consumo - material para comunicações
# 33  Out.Serv.de Tercerizaçao-P.Jurídica - Cooperat...
# 37  Outros Serv.Terceiros - P. Juridica - Serviços...
#
#                                             Descricao    Codigo  \
# 53  Vencimento e vantagens fixas Pessoal Civil (Ve...  31901101
# 5   Contribuição para o Regime Geral de Previdênci...  31901301
# 32  Outros Despesas de Pessoal – Terceirização – P...  33903401
# 6   Contribuição para o Regime Próprio de Previdên...  31911302
# 54     Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 34  Outros Despesas de Pessoal – Terceirização – P...  33903401
# 35     Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 36     Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 12                            Estagiários e Monitores  33903603
# 41                           Publicidade e Propaganda  33903901
# 1                                  Auxílio-Transporte  33904900
# 3                Bens Móveis – Veículos e Embarcações  44905202
# 9                                     Diárias – Civil  33901400
# 4                        Combustíveis e Lubrificantes  33903002
# 51                              Serviços de Telefonia  33903909
# 45  Serviços de Tecnologia da Informação e Comunic...  33904000
# 46  Serviços de Tecnologia da Informação e Comunic...  33904000
# 14                  Juros sobre a Dívida por Contrato  32902100
# 19                       Material de Consumo – Outros  33903099
# 10             Equipamentos de Processamento de Dados  44905201
# 7                                    Passagens Aéreas  33903301
# 11    Equipamentos e Materiais Permanentes – Diversos  44905206
# 52                         Suprimentos de Informática  33903001
# 29                 Material de Escritório, Expediente  33903003
# 28               Material para Manutenção de Veículos  33903006
# 13                      Gêneros Alimentícios – Outros  33903012
# 49                 Serviços de Cópias e Encadernações  33903912
# 27           Material para Manutenção de Bens Imóveis  33903008
# 42     Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 50                   Serviços de Fornecimento de Água  33903911
# 48                                  Serviços Gráficos  33903907
# 43  Serviços prestados por profissionais técnicos ...  33903608
# 39       Outros Serviços de Terceiros - Pessoa Física  33903699
# 22                       Material de Consumo – Outros  33903099
# 17                                Locação de Software  33903915
# 23                       Material de Consumo – Outros  33903099
# 0      Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 18     Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 31             Obrigações Tributárias e Contributivas  33904700
# 44  Serviços prestados por profissionais técnicos ...  33903608
# 26  Material para Manutenção de Máquinas e Embarca...  33903009
# 2                   Bens Móveis – Móveis e Utensílios  44905204
# 30                 Material de Processamento de Dados  33903005
# 15       Outros Serviços de Terceiros - Pessoa Física  33903699
# 25                       Material de Consumo – Outros  33903099
# 20                       Material de Consumo – Outros  33903099
# 47     Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 21                       Material de Consumo – Outros  33903099
# 16                                Locação de Software  44903915
# 8                                Passagens Terrestres  33903302
# 38     Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 40     Outros Serviços de Terceiros - Pessoa Jurídica  44903999
# 24                       Material de Consumo – Outros  33903099
# 33  Outros Despesas de Pessoal – Terceirização – P...  33903401
# 37     Outros Serviços de Terceiros - Pessoa Jurídica  33903999
#
#                   value
# 53        52,615,516.90
# 5          9,429,752.94
# 32         4,203,960.97
# 6          4,100,618.79
# 54         3,685,384.81
# 34         2,618,000.00
# 35         2,234,539.90
# 36         1,958,420.39
# 12         1,013,204.78
# 41           618,865.50
# 1            595,188.57
# 3            413,400.00
# 9            407,895.00
# 4            383,318.57
# 51           341,422.95
# 45           338,639.89
# 46           288,479.98
# 14           267,531.13
# 19           263,064.46
# 10           168,147.00
# 7            158,089.39
# 11           156,462.00
# 52            87,340.80
# 29            84,664.53
# 28            83,209.80
# 13            74,332.97
# 49            59,861.82
# 27            39,915.60
# 42            33,497.97
# 50            33,182.04
# 48            30,659.93
# 43            26,838.00
# 39            26,559.10
# 22            24,412.12
# 17            20,795.93
# 23            16,206.06
# 0             15,756.00
# 18            14,683.33
# 31            14,634.12
# 44            14,200.00
# 26            12,372.72
# 2             11,850.00
# 30             6,750.00
# 15             4,180.00
# 25             3,950.00
# 20             2,800.00
# 47             2,013.33
# 21             1,400.00
# 16             1,260.00
# 8              1,126.80
# 38               778.19
# 40               550.00
# 24               149.70
# 33               116.79
# 37            -6,500.00

# %%
plt.figure(figsize=(16,8))
plot = sns.barplot(
    data=despesas_com_classificacao,
    x='Descricao',
    y='value',
    estimator=sum,
    palette=sns.color_palette("BuGn_r", n_colors=len(despesas_com_classificacao) + 4)
)
plot.set_xticklabels(plot.get_xticklabels(), rotation=75, horizontalalignment='right')
plt.show()

# %%
vencimentos = ['Vencimentos e Vantagens Fixas - Pessoal Civil', 'Vencimento e vantagens fixas Pessoal Civil (Vencimento Básico)']
despesas_sem_vencimentos = despesas_com_classificacao[~despesas_com_classificacao['Descricao'].isin(vencimentos)]

plt.figure(figsize=(16,8))
plot = sns.barplot(
    data=despesas_sem_vencimentos,
    x='Descricao',
    y='value',
    estimator=sum,
    palette=sns.color_palette("muted", n_colors=len(despesas_sem_vencimentos) + 4)
)
plot.set_xticklabels(plot.get_xticklabels(), rotation=75, horizontalalignment='right')
plt.show()

# %%
sns.catplot(
    x="value",
    y="Descricao",
    col="month",
    data=despesas_com_classificacao, kind="bar",
    height=4, aspect=.7
)

# %%
despesas_com_classificacao[['legal_status', 'subgroup', 'Descricao', 'summary', 'Codigo']].head(100)
# Out:
#                                          legal_status  \
# 0   319011010000 - V.Vant.Fixas P.Civil(Ve.Base Fo...
# 1   319011010000 - V.Vant.Fixas P.Civil(Ve.Base Fo...
# 2   339039999300000000 - Serviços Bancários       ...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95  319113020000 - Cont.p/Reg.Proprio Prev.ser.RPP...
# 96  339039999900 - Outros Serv.Terceiros - P. Juri...
# 97  339039010000000000 - Publicidades e Propaganda...
# 98  319113020000000000 - Cont.p/Reg.Proprio Prev.s...
# 99  339039999900000000 - Outros Serv.Terceiros - P...
#
#                                              subgroup  \
# 0                 V.Vant.Fixas P.Civil(Ve.Base Folha)
# 1                 V.Vant.Fixas P.Civil(Ve.Base Folha)
# 2                                  Serviços Bancários
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                   Cont.p/Reg.Proprio Prev.ser.RPPS
# 96                Outros Serv.Terceiros - P. Juridica
# 97                          Publicidades e Propaganda
# 98                   Cont.p/Reg.Proprio Prev.ser.RPPS
# 99  Outros Serv.Terceiros - P. Juridica - Demais s...
#
#                                             Descricao  \
# 0   Vencimento e vantagens fixas Pessoal Civil (Ve...
# 1   Vencimento e vantagens fixas Pessoal Civil (Ve...
# 2      Outros Serviços de Terceiros - Pessoa Jurídica
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95  Contribuição para o Regime Próprio de Previdên...
# 96     Outros Serviços de Terceiros - Pessoa Jurídica
# 97                           Publicidade e Propaganda
# 98  Contribuição para o Regime Próprio de Previdên...
# 99     Outros Serviços de Terceiros - Pessoa Jurídica
#
#                                               summary    Codigo
# 0   REF. A VENCIMENTOS DOS SERVIDORES EFETIVOS, FO...  31901101
# 1   REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...  31901101
# 2      ANULACAO PARCIAL DO EMPENHO DE NUMERO 19000533  33903999
# 3          PAGAMENTO EXTRA-ORCAMENTARIO NUMERO:000403       NaN
# 4          PAGAMENTO EXTRA-ORCAMENTARIO NUMERO:000402       NaN
# ..                                                ...       ...
# 95  REF. A OBRIGAÇÕES PATRONAIS SOBRE FOLHA DE PAG...  31911302
# 96  REF. A SERVIÇO DE EXECUÇÃO DO PLANEJAMENTO TÉC...  33903999
# 97     ANULACAO PARCIAL DO EMPENHO DE NUMERO 19000547  33903901
# 98     ANULACAO PARCIAL DO EMPENHO DE NUMERO 19000502  31911302
# 99     ANULACAO PARCIAL DO EMPENHO DE NUMERO 19000018  33903999
#
# [100 rows x 5 columns]

# %%
# Auxílio-Alimentação
# Vale refeição/vale alimentação

# Encargos pela Honra de Avais, Garantias, Seguros e Similares

# %%
# Locacao de Software / Locaçao de Software
# Materiais de Consumo - gás e outros / Materiais de Consumo - gás e outros materiais ...

# %%
despesas = despesas[despesas['phase'] == 'pagamento']
despesas.describe()['value']
# Out:
# count               1,706.00
# mean               16,744.04
# std                65,200.25
# min                -1,232.89
# 25%                   168.91
# 50%                   905.00
# 75%                 4,705.15
# max               719,758.96
# Name: value, dtype: float64

# %%
pd.options.display.float_format = '{:20,.2f}'.format
despesas['value'].describe()
# Out:
# count               1,706.00
# mean               16,744.04
# std                65,200.25
# min                -1,232.89
# 25%                   168.91
# 50%                   905.00
# 75%                 4,705.15
# max               719,758.96
# Name: value, dtype: float64

# %%
despesas.nlargest(20, 'value')[['date', 'value', 'summary', 'subgroup', 'phase']]
# Out:
#             date                value  \
# 31693 2019-02-21           719,758.96
# 32238 2019-04-17           694,826.01
# 31968 2019-03-21           691,621.10
# 32635 2019-05-20           684,911.34
# 33792 2019-09-20           684,425.13
# 33421 2019-08-20           683,621.63
# 31665 2019-01-22           682,234.89
# 32980 2019-06-19           680,490.41
# 34395 2019-11-20           680,197.84
# 33173 2019-07-19           679,767.91
# 33974 2019-10-18           678,048.28
# 34761 2019-12-20           307,464.32
# 32843 2019-06-11           292,669.93
# 34676 2019-12-12           283,967.22
# 33966 2019-10-18           210,484.68
# 32968 2019-06-19           207,105.85
# 34318 2019-11-20           200,554.12
# 32237 2019-04-17           200,368.32
# 34775 2019-12-20           199,000.00
# 32335 2019-04-22           192,309.26
#
#                                                  summary  \
# 31693                REF. REMUNERAÇÃO DE FEVEREIRO 2019.
# 32238  EF. A VENCIMENTOS DOS SERVIDORES CARGOS EM COM...
# 31968  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...
# 32635                     REF. REMUNERAÇÃO DE MAIO 2019.
# 33792  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...
# 33421  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...
# 31665  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...
# 32980  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...
# 34395  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...
# 33173  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...
# 33974  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...
# 34761  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...
# 32843  REF A ADIANTAMENTO DO 13° SALÁRIO DOS SERVIDOR...
# 34676  REF. A 2ª PARCELA DO 13º SALÁRIO DOS SERVIDORE...
# 33966  REF. A VENCIMENTOS DOS SERVIDORES EFETIVOS, MÊ...
# 32968  REF. A VENCIMENTOS DOS SERVIDORES EFETIVOS, MÊ...
# 34318  REF. A VENCIMENTOS DOS SERVIDORES EFETIVOS, MÊ...
# 32237  REF. A VENCIMENTOS DOS SERVIDORES EFETIVOS, MÊ...
# 34775  REF. A VENCIMENTOS DOS SERVIDORES CARGOS EM CO...
# 32335  REF. A OBRIGAÇÕES PATRONAIS SOBRE FOLHA DE PAG...
#
#                                   subgroup      phase
# 31693  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 32238  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 31968  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 32635  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 33792  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 33421  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 31665  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 32980  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 34395  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 33173  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 33974  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 34761  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 32843  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 34676  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 33966  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 32968  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 34318  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 32237  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 34775  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 32335           Cont.p/Reg.Geral Prev.INSS  pagamento

# %%
despesas.nsmallest(20, 'value')[['date', 'value', 'summary', 'subgroup', 'phase']]
# Out:
#             date                value  \
# 33884 2019-10-04            -1,232.89
# 31571 2019-01-23                 0.50
# 33941 2019-10-09                 1.38
# 32414 2019-05-06                 1.38
# 33613 2019-09-11                 1.62
# 33503 2019-09-02                 1.62
# 33412 2019-08-07                 1.62
# 33078 2019-07-05                 1.62
# 31619 2019-02-18                 1.62
# 31392 2019-01-16                 1.62
# 32961 2019-06-18                 2.76
# 31725 2019-03-07                 2.76
# 34148 2019-11-08                 3.24
# 34438 2019-11-06                 3.24
# 33553 2019-08-20                 3.24
# 32925 2019-06-17                 3.24
# 31387 2019-01-11                 3.24
# 34933 2019-12-26                 3.99
# 32791 2019-06-05                 4.38
# 34232 2019-11-26                 4.65
#
#                                               summary  \
# 33884                                             NaN
# 31571      PAGAMENTO EXTRA-ORCAMENTARIO NUMERO:000022
# 33941  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 32414  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 33613  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 33503  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 33412  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 33078  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 31619                REF. TARIFA BANCARIA NESTA DATA.
# 31392  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 32961  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 31725                REF. TARIFA BANCARIA NESTA DATA.
# 34148  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 34438  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 33553  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 32925  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 31387  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 34933      PAGAMENTO EXTRA-ORCAMENTARIO NUMERO:000400
# 32791  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# 34232  REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
#
#                                   subgroup      phase
# 33884  V.Vant.Fixas P.Civil(Ve.Base Folha)  pagamento
# 31571                                  NaN  pagamento
# 33941                   Serviços Bancários  pagamento
# 32414                   Serviços Bancários  pagamento
# 33613                   Serviços Bancários  pagamento
# 33503                   Serviços Bancários  pagamento
# 33412                   Serviços Bancários  pagamento
# 33078                   Serviços Bancários  pagamento
# 31619                   Serviços Bancários  pagamento
# 31392                   Serviços Bancários  pagamento
# 32961                   Serviços Bancários  pagamento
# 31725                   Serviços Bancários  pagamento
# 34148                   Serviços Bancários  pagamento
# 34438                   Serviços Bancários  pagamento
# 33553                   Serviços Bancários  pagamento
# 32925                   Serviços Bancários  pagamento
# 31387                   Serviços Bancários  pagamento
# 34933                                  NaN  pagamento
# 32791                   Serviços Bancários  pagamento
# 34232                   Serviços Bancários  pagamento

# %% [markdown]
# ## Quem foram os fornecedores?

# %%
pd.pivot_table(
    despesas, 
    values='value',
    index=['company_or_person'],
    columns='month',
    aggfunc=np.sum
).sort_values(by='company_or_person', ascending=False)
# Out:
# month                                                          1   \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME                  nan
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                         nan
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                        nan
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                            nan
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# month                                                          2   \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME             1,249.16
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                         nan
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                     691.53
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                            nan
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# month                                                          3   \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME             1,258.06
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                         nan
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                     690.96
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                            nan
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# month                                                          4   \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                               1,320.00
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME                  nan
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                         nan
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                     690.53
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                            nan
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# month                                                          5   \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME             2,516.60
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                      690.46
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                        nan
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                    3,600.00
# ALBERTO MATOS NERY                                            nan
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                            1,290.70
#
# month                                                          6   \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME             1,259.12
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                      690.46
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                        nan
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                      1,936.91
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                       3,600.00
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# month                                                          7   \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME             1,259.66
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                      690.46
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                        nan
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                            nan
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# month                                                          8   \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME             1,260.31
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                      689.38
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                        nan
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                            nan
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# month                                                          9   \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME             1,260.31
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                      689.38
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                        nan
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                       1,350.00
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# month                                                          10  \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME             1,260.63
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                         nan
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                        nan
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                            nan
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# month                                                          11  \
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME             1,261.67
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                      689.31
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                        nan
# VIDROCA COML. DE VIDROS E CALH                              92.15
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                         400.00
# AILTON OLIVEIRA BRITO JUNIOR                                  nan
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# month                                                          12
# company_or_person
# WELLIGTON ANDRADE DE JESUS                                    nan
# W. AGUIAR CABRAL DOS SANTOS SONORIZAÇÃO - ME             2,525.50
# VIPSEL SEGURANÇA MONITORADA EIRELI ME                         nan
# VIP'SEL SEGURANÇA MONITORADA EIRELI ME                        nan
# VIDROCA COML. DE VIDROS E CALH                                nan
# ...                                                           ...
# ALLIANZ SEGUROS S/A                                           nan
# ALDNEY BASTOS MARQUES                                         nan
# ALBERTO MATOS NERY                                            nan
# AILTON OLIVEIRA BRITO JUNIOR                               125.00
# 305 COMERCIO DE UTILIDADES DO                                 nan
#
# [177 rows x 12 columns]

# %%
def to_csv(despesas, arquivo='todas-as-despesas-desde-2016.csv'):
    despesas.to_csv(
        arquivo,
        index=False,
        columns=["published_at", "phase", "company_or_person", "value", "number", "document", "date", "process_number", "summary", "group", "function", "subfunction", "type_of_process", "resource"],
        header=["publicado_em", "fase", "empresa_ou_pessoa", "valor", "numero", "documento", "data", "numero_do_processo", "sumario", "grupo", "funcao", "subfuncao", "type_of_process", "fonte"]
    )

# %%
despesas.groupby('type_of_process')['value'].sum().plot(kind='bar')
plt.show()

despesas.groupby('group')['value'].sum().plot(kind='bar')
plt.show()

despesas.groupby('group')['value'].sum().plot(kind='bar')
plt.show()

# %%
despesas.group.value_counts()
# Out:
# Manutencao dos servicos tecnico administrativos    875
# Administracao de pessoal e encargos                434
# Administracao da acao legislativa                   83
# Name: group, dtype: int64

# %%
despesas.company_or_person.value_counts()
# Out:
# CAIXA ECONOMICA FEDERAL                                  172
# IPFS - INST. DE PREV. DOS SERV                           101
# REDE GERAL SERVIÇOS LTDA ME                               65
# FUNCIONARIOS CARGOS EM COMISSA                            55
# INSS - INST. NAC. DE SEG. SOCI                            51
#                                                         ...
# JAI TRANSPORTE E COMÉRCIO DE GÁS LTDA                      1
# DNIT-DEPARTAMENTO NACIONAL DE INFRAEST DE TRANSPORTES      1
# JOÃO DOS SANTOS                                            1
# RODRIGUES E FARIAS LTDA.                                   1
# ROBECI SILVA LIMA                                          1
# Name: company_or_person, Length: 177, dtype: int64

# %%
despesas.groupby(['company_or_person']).sum().groupby(level=[0])['value'].cumsum().sort_values(ascending=False)
# Out:
# company_or_person
# FUNCIONARIOS CARGOS EM COMISSA                                 8,934,114.84
# INSS - INST. NAC. DE SEG. SOCI                                 3,100,402.72
# FUNCIONARIOS EFETIVOS                                          2,520,349.98
# VEREADORES                                                     2,452,739.15
# ESFERA PRODUÇÃO E EVENTOS EIRELI-ME                            1,616,129.37
#                                                                ...
# MARIA CLARA PIRES DA PURIFICAÇÃO                                     125.00
# VIDROCA COML. DE VIDROS E CALH                                        92.15
# PROTONLUZ COMERCIO DE MATERIAIS ELEÉTRICOS LTDA - ME                  66.80
# RETENCOES DIVERSAS                                                    40.19
# DESCONTO AUTORIZADO                                                    0.50
# Name: value, Length: 177, dtype: float64

# %% [markdown]
# ## O que a Câmara consome mais em cada categoria?

# %%
despesas_com_classificacao['summary'].describe()
# Out:
# count                                               3696
# unique                                              1876
# top       REF. A TARIFA BANCÁRIA SOBRE CONTA DESTA CASA.
# freq                                                 276
# Name: summary, dtype: object

# %%
despesas_com_classificacao[['Descricao', 'Codigo', 'summary', 'value']].tail(20)
# Out:
#                                            Descricao    Codigo  \
# 3689  Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 3690                   Gêneros Alimentícios – Outros  33903012
# 3691  Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 3692                                Passagens Aéreas  33903301
# 3693  Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 3694                           Serviços de Telefonia  33903909
# 3695                             Locação de Software  44903915
# 3696                           Serviços de Telefonia  33903909
# 3697                                             NaN       NaN
# 3698                           Serviços de Telefonia  33903909
# 3699          Obrigações Tributárias e Contributivas  33904700
# 3700                                             NaN       NaN
# 3701                              Auxílio-Transporte  33904900
# 3702  Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 3703  Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 3704  Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 3705  Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 3706  Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 3707  Outros Serviços de Terceiros - Pessoa Jurídica  33903999
# 3708  Outros Serviços de Terceiros - Pessoa Jurídica  33903999
#
#                                                 summary                value
# 3689  IMPORTE DESTINADO A PAGAMENTO DE DESPESAS COM ...           120,000.00
# 3690           IMPORTE DESTINADO A GENEROS ALIMENTICIOS            10,000.00
# 3691  IMPOSTE DESTINADO A PAGAMENTO DE DESPESA COM T...           104,800.00
# 3692  IMPORTE DESTINADO A PAGAMENTO DE PASSAGENS AEREAS            10,000.00
# 3693  IMPOSTE DESTINADO A PAGAMENTO DE DESPESA COM S...            10,800.00
# 3694  IMPORTE DESTINADO A PAGAMENTO DE DESPESAS COM ...            26,608.00
# 3695  IMPOSTE DESTINADO A PAGAMENTO DE DESPESAS COM ...             1,260.00
# 3696  IMPORTE DESTINADO A DESPESA DE PAGAMENTO COM T...             5,400.00
# 3697  IMPORTE DESTINADO A PAGAMENTO DE DIVIDA PREVID...            44,875.08
# 3698  IMPOSTE DESTINADO A PAGAMENTO DE DESPESAS COM ...            26,608.00
# 3699     IMPORTE DESTINADO A PAGAMENTO DE INSS(SERVIÇO)            10,000.00
# 3700  SERVIÇO DE REMANUFATURA DE CARTUCHOS HP PARA A...             3,000.00
# 3701  IMPORTE DESTINADO A PAGAMENTO DE AUX TRANSPORT...           140,000.00
# 3702  IMPORTE DESTINADO A PAGAMENTO DE DESPESAS COM ...             6,675.00
# 3703  IMPORTE DESTINADO A PAGAMENTO DE DESPESAS COM ...             1,300.00
# 3704  IMPORTE DESTINADO A PAGAMENTO DE DESPESAS COM ...            10,000.00
# 3705  IMPORTE DESTINADO A PAGAMENTO DE DESPESAS COM ...            10,000.00
# 3706  IMPOSTE DESTINADO A PAGAMENTO DE DESPESAS COM ...             2,340.00
# 3707  IMPORTE DESTINADO A PAGAMENTO DE DESPESA COM T...           104,800.00
# 3708  IMPORTE DESTINADO A PAGAMENTO DE DESPESAS COM ...             1,120.00

# %%
despesas.groupby(
    ['company_or_person', 'document']
).size().reset_index().rename(columns={0: 'count'}).sort_values('count', ascending=False)
# Out:
#                            company_or_person            document  count
# 17                   CAIXA ECONOMICA FEDERAL  00.360.305/1611-16    172
# 84            IPFS - INST. DE PREV. DOS SERV  42.743.658/0001-33    101
# 139              REDE GERAL SERVIÇOS LTDA ME  08.241.186/0001-82     65
# 66            FUNCIONARIOS CARGOS EM COMISSA  14.488.415/0001-60     55
# 83            INSS - INST. NAC. DE SEG. SOCI  29.979.036/0001-40     51
# ..                                       ...                 ...    ...
# 73                   HARLEN DA SILVA ALMEIDA  09.442.874/0001-73      1
# 71                 GILMAR AMORIM DE OLIVEIRA      733.533.025-49      1
# 70            GERUSA MARIA BASTOS S. SAMPAIO      272.179.495-72      1
# 62   FAGUNDES E BITENCOURT DESPACHANTES LTDA  29.780.653/0001-12      1
# 176               WELLIGTON ANDRADE DE JESUS      248.035.295-15      1
#
# [177 rows x 3 columns]

# %%
import re


padrao = {
    re.compile('\d{2}.?\d{3}.?\d{3}/?\d{4}-?\d{2}'): "jurídica",
    re.compile('\d{3}\.\d{3}\.\d{3}\-\d{2}'): "física"
}


despesas['tipo_de_pessoa'] = despesas['document'].replace(padrao, regex=True)
print(despesas.groupby(['tipo_de_pessoa']).size())

despesas['tipo_de_pessoa'].value_counts().plot.pie(
    y='tipo_de_pessoa', title="Pessoa física ou jurídica?", autopct='%1.1f%%', startangle=0
)
# Out:
# tipo_de_pessoa
# física       304
# jurídica    1402
# dtype: int64
