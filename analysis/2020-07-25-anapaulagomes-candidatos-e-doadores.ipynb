# %% [markdown]
# # Candidatos, doações e doadores
#
# Fonte dos dados: TSE
#
# Dicionário de dados: `leiame_receitas-candidatos.pdf`
#
# Observações sobre os dados:
#
# * `#NULO` é o mesmo que `None`
# * `#NE` significa que naquele ano a informação não era registrada
# * Campo `UF`: `BR` para nível nacional, `VT` voto em trânsito e `ZZ` para Exterior
# * Campo `NM_UE`, no caso de eleições municipais, é o nome do município

# %%
import pandas as pd


df = pd.read_csv("receitas_candidatos_2020_BA.csv", encoding="latin", delimiter=";")
df.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0  16/10/2020   04:06:04         2020                2       Ordinária
# 1  16/10/2020   04:06:04         2020                2       Ordinária
# 2  16/10/2020   04:06:04         2020                2       Ordinária
# 3  16/10/2020   04:06:04         2020                2       Ordinária
# 4  16/10/2020   04:06:04         2020                2       Ordinária
#
#    CD_ELEICAO                DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 0         426  Eleições Municipais 2020  15/11/2020         1
# 1         426  Eleições Municipais 2020  15/11/2020         1
# 2         426  Eleições Municipais 2020  15/11/2020         1
# 3         426  Eleições Municipais 2020  15/11/2020         1
# 4         426  Eleições Municipais 2020  15/11/2020         1
#
#     TP_PRESTACAO_CONTAS  ... DS_CARGO_CANDIDATO_DOADOR  NR_PARTIDO_DOADOR  \
# 0  Relatório Financeiro  ...                    #NULO#                 -1
# 1  Relatório Financeiro  ...                    #NULO#                 -1
# 2  Relatório Financeiro  ...                    #NULO#                 -1
# 3  Relatório Financeiro  ...                    #NULO#                 -1
# 4  Relatório Financeiro  ...                    #NULO#                 -1
#
#   SG_PARTIDO_DOADOR  NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 0            #NULO#             #NULO#  652611336293BA000001E
# 1            #NULO#             #NULO#                 #NULO#
# 2            #NULO#             #NULO#                 #NULO#
# 3            #NULO#             #NULO#                 #NULO#
# 4            #NULO#             #NULO#                 #NULO#
#
#        NR_DOCUMENTO_DOACAO  SQ_RECEITA  DT_RECEITA  DS_RECEITA  VR_RECEITA
# 0                   #NULO#    12689879  07/10/2020      #NULO#      500,00
# 1                      283    12733000  08/10/2020      #NULO#      190,00
# 2  00000000000000000001950    12767280  14/10/2020      #NULO#      320,00
# 3  00000006493855197167616    12722035  28/09/2020      #NULO#      850,00
# 4  00000000000000000001578    12717118  01/10/2020      #NULO#     1040,00
#
# [5 rows x 57 columns]

# %%
df_feira = df[df["NM_UE"] == "FEIRA DE SANTANA"]
df_feira
# Out:
#       DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 29    16/10/2020   04:06:04         2020                2       Ordinária
# 30    16/10/2020   04:06:04         2020                2       Ordinária
# 31    16/10/2020   04:06:04         2020                2       Ordinária
# 34    16/10/2020   04:06:04         2020                2       Ordinária
# 39    16/10/2020   04:06:04         2020                2       Ordinária
# ...          ...        ...          ...              ...             ...
# 4671  16/10/2020   04:06:04         2020                2       Ordinária
# 4672  16/10/2020   04:06:04         2020                2       Ordinária
# 4674  16/10/2020   04:06:04         2020                2       Ordinária
# 4713  16/10/2020   04:06:04         2020                2       Ordinária
# 4744  16/10/2020   04:06:04         2020                2       Ordinária
#
#       CD_ELEICAO                DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 29           426  Eleições Municipais 2020  15/11/2020         1
# 30           426  Eleições Municipais 2020  15/11/2020         1
# 31           426  Eleições Municipais 2020  15/11/2020         1
# 34           426  Eleições Municipais 2020  15/11/2020         1
# 39           426  Eleições Municipais 2020  15/11/2020         1
# ...          ...                       ...         ...       ...
# 4671         426  Eleições Municipais 2020  15/11/2020         1
# 4672         426  Eleições Municipais 2020  15/11/2020         1
# 4674         426  Eleições Municipais 2020  15/11/2020         1
# 4713         426  Eleições Municipais 2020  15/11/2020         1
# 4744         426  Eleições Municipais 2020  15/11/2020         1
#
#        TP_PRESTACAO_CONTAS  ... DS_CARGO_CANDIDATO_DOADOR  NR_PARTIDO_DOADOR  \
# 29    Relatório Financeiro  ...                    #NULO#                 -1
# 30    Relatório Financeiro  ...                    #NULO#                 -1
# 31    Relatório Financeiro  ...                    #NULO#                 -1
# 34    Relatório Financeiro  ...                    #NULO#                 -1
# 39    Relatório Financeiro  ...                    #NULO#                 -1
# ...                    ...  ...                       ...                ...
# 4671  Relatório Financeiro  ...                  Vereador                 40
# 4672  Relatório Financeiro  ...                  Vereador                 40
# 4674  Relatório Financeiro  ...                  Vereador                 40
# 4713  Relatório Financeiro  ...                  Prefeito                 13
# 4744  Relatório Financeiro  ...                  Vereador                 65
#
#      SG_PARTIDO_DOADOR              NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 29              #NULO#                         #NULO#                 #NULO#
# 30              #NULO#                         #NULO#                 #NULO#
# 31              #NULO#                         #NULO#                 #NULO#
# 34              #NULO#                         #NULO#                 #NULO#
# 39              #NULO#                         #NULO#                 #NULO#
# ...                ...                            ...                    ...
# 4671               PSB  Partido Socialista Brasileiro  402341335157BA000001E
# 4672               PSB  Partido Socialista Brasileiro  402341335157BA000002E
# 4674               PSB  Partido Socialista Brasileiro  402241335157BA000001E
# 4713                PT      Partido dos Trabalhadores  000131135157BA000001E
# 4744           PC do B    Partido Comunista do Brasil  651231335157BA000001E
#
#           NR_DOCUMENTO_DOACAO  SQ_RECEITA  DT_RECEITA  DS_RECEITA  VR_RECEITA
# 29    00000005209657425526784    12729226  30/09/2020      #NULO#      210,00
# 30    00000006104203751587840    12738862  29/09/2020      #NULO#     2695,00
# 31    00000005354794772332544    12720687  29/09/2020      #NULO#     1270,00
# 34                  661253128    12757435  13/10/2020      #NULO#     3070,00
# 39                  652687107    12757113  09/10/2020      #NULO#      370,00
# ...                       ...         ...         ...         ...         ...
# 4671          603128000035377    12644992  06/10/2020      #NULO#     1200,00
# 4672              10076461587    12644993  06/10/2020      #NULO#      800,00
# 4674              21377723534    12585607  06/10/2020      #NULO#      400,00
# 4713                     0001    12675635  01/10/2020      #NULO#    50000,00
# 4744                   2A32AA    12613629  07/10/2020      #NULO#     1020,00
#
# [219 rows x 57 columns]

# %%
fields = [
    "TP_PRESTACAO_CONTAS", "NM_CANDIDATO", "NR_CPF_CANDIDATO", "NR_CPF_VICE_CANDIDATO", "DS_CARGO",
    "NR_PARTIDO", "SG_PARTIDO", "NM_PARTIDO", "CD_FONTE_RECEITA", "DS_FONTE_RECEITA", "CD_ORIGEM_RECEITA",
    "DS_ORIGEM_RECEITA", "CD_NATUREZA_RECEITA", "DS_NATUREZA_RECEITA", "CD_ESPECIE_RECEITA", "DS_ESPECIE_RECEITA",
    "CD_CNAE_DOADOR", "DS_CNAE_DOADOR", "NR_CPF_CNPJ_DOADOR", "NM_DOADOR", "NM_DOADOR_RFB", "CD_ESFERA_PARTIDARIA_DOADOR",
    "DS_ESFERA_PARTIDARIA_DOADOR", "SG_UF_DOADOR", "CD_MUNICIPIO_DOADOR", "NM_MUNICIPIO_DOADOR", "SQ_CANDIDATO_DOADOR",
    "NR_CANDIDATO_DOADOR", "CD_CARGO_CANDIDATO_DOADOR", "DS_CARGO_CANDIDATO_DOADOR", "NR_PARTIDO_DOADOR", "SG_PARTIDO_DOADOR",
    "NM_PARTIDO_DOADOR", "NR_RECIBO_DOACAO", "NR_DOCUMENTO_DOACAO", "SQ_RECEITA", "DT_RECEITA", "DS_RECEITA", "VR_RECEITA"
]

df_filtered = df_feira[fields]
df_filtered
# Out:
#        TP_PRESTACAO_CONTAS                        NM_CANDIDATO  \
# 29    Relatório Financeiro          VALDEMAR DA SILVA OLIVEIRA
# 30    Relatório Financeiro  JESSICA FEITOSA APOLINARIO CORREIA
# 31    Relatório Financeiro   JUAN PABLO MARTINS DANTAS DA CRUZ
# 34    Relatório Financeiro              JHONATAS LIMA MONTEIRO
# 39    Relatório Financeiro                       MARCELA PREST
# ...                    ...                                 ...
# 4671  Relatório Financeiro          ANTÔNIO CARLOS DE OLIVEIRA
# 4672  Relatório Financeiro          ANTÔNIO CARLOS DE OLIVEIRA
# 4674  Relatório Financeiro       CARLOS ALBERTO COSTA DA ROCHA
# 4713  Relatório Financeiro      JOSE CERQUEIRA DE SANTANA NETO
# 4744  Relatório Financeiro    JOSE RAIMUNDO DO ROSARIO CAZUMBA
#
#       NR_CPF_CANDIDATO  NR_CPF_VICE_CANDIDATO  DS_CARGO  NR_PARTIDO  \
# 29           620720565                     -1  Vereador          30
# 30          4130735560                     -1  Vereador          30
# 31          6378691509                     -1  Vereador          30
# 34          1121246583                     -1  Vereador          50
# 39         12709994780             2099711500  Prefeito          50
# ...                ...                    ...       ...         ...
# 4671       10075461587                     -1  Vereador          40
# 4672       10075461587                     -1  Vereador          40
# 4674       21377723534                     -1  Vereador          40
# 4713       38247186500            63674815591  Prefeito          13
# 4744       31498680500                     -1  Vereador          65
#
#      SG_PARTIDO                      NM_PARTIDO  CD_FONTE_RECEITA  \
# 29         NOVO                    Partido Novo                 1
# 30         NOVO                    Partido Novo                 1
# 31         NOVO                    Partido Novo                 1
# 34         PSOL  Partido Socialismo e Liberdade                 1
# 39         PSOL  Partido Socialismo e Liberdade                 1
# ...         ...                             ...               ...
# 4671        PSB   Partido Socialista Brasileiro                 1
# 4672        PSB   Partido Socialista Brasileiro                 1
# 4674        PSB   Partido Socialista Brasileiro                 1
# 4713         PT       Partido dos Trabalhadores                 1
# 4744    PC do B     Partido Comunista do Brasil                 1
#
#      DS_FONTE_RECEITA  ...  DS_CARGO_CANDIDATO_DOADOR NR_PARTIDO_DOADOR  \
# 29    Outros Recursos  ...                     #NULO#                -1
# 30    Outros Recursos  ...                     #NULO#                -1
# 31    Outros Recursos  ...                     #NULO#                -1
# 34    Outros Recursos  ...                     #NULO#                -1
# 39    Outros Recursos  ...                     #NULO#                -1
# ...               ...  ...                        ...               ...
# 4671  Outros Recursos  ...                   Vereador                40
# 4672  Outros Recursos  ...                   Vereador                40
# 4674  Outros Recursos  ...                   Vereador                40
# 4713  Outros Recursos  ...                   Prefeito                13
# 4744  Outros Recursos  ...                   Vereador                65
#
#       SG_PARTIDO_DOADOR              NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 29               #NULO#                         #NULO#                 #NULO#
# 30               #NULO#                         #NULO#                 #NULO#
# 31               #NULO#                         #NULO#                 #NULO#
# 34               #NULO#                         #NULO#                 #NULO#
# 39               #NULO#                         #NULO#                 #NULO#
# ...                 ...                            ...                    ...
# 4671                PSB  Partido Socialista Brasileiro  402341335157BA000001E
# 4672                PSB  Partido Socialista Brasileiro  402341335157BA000002E
# 4674                PSB  Partido Socialista Brasileiro  402241335157BA000001E
# 4713                 PT      Partido dos Trabalhadores  000131135157BA000001E
# 4744            PC do B    Partido Comunista do Brasil  651231335157BA000001E
#
#           NR_DOCUMENTO_DOACAO  SQ_RECEITA  DT_RECEITA  DS_RECEITA VR_RECEITA
# 29    00000005209657425526784    12729226  30/09/2020      #NULO#     210,00
# 30    00000006104203751587840    12738862  29/09/2020      #NULO#    2695,00
# 31    00000005354794772332544    12720687  29/09/2020      #NULO#    1270,00
# 34                  661253128    12757435  13/10/2020      #NULO#    3070,00
# 39                  652687107    12757113  09/10/2020      #NULO#     370,00
# ...                       ...         ...         ...         ...        ...
# 4671          603128000035377    12644992  06/10/2020      #NULO#    1200,00
# 4672              10076461587    12644993  06/10/2020      #NULO#     800,00
# 4674              21377723534    12585607  06/10/2020      #NULO#     400,00
# 4713                     0001    12675635  01/10/2020      #NULO#   50000,00
# 4744                   2A32AA    12613629  07/10/2020      #NULO#    1020,00
#
# [219 rows x 39 columns]

# %%
mayor_df = df_filtered[df_filtered["DS_CARGO"] == "Prefeito"]
mayor_df  # doação a prefeitos de Feira de Santana
# Out:
#        TP_PRESTACAO_CONTAS                                 NM_CANDIDATO  \
# 39    Relatório Financeiro                                MARCELA PREST
# 398   Relatório Financeiro  DAYANE JAMILLE CARNEIRO DOS SANTOS PIMENTEL
# 401   Relatório Financeiro  DAYANE JAMILLE CARNEIRO DOS SANTOS PIMENTEL
# 556   Relatório Financeiro               JOSE CERQUEIRA DE SANTANA NETO
# 584   Relatório Financeiro               ROBERTO LUIS DA SILVA TOURINHO
# 706   Relatório Financeiro                      CARLOS MEDEIROS MIRANDA
# 707   Relatório Financeiro                      CARLOS MEDEIROS MIRANDA
# 708   Relatório Financeiro                      CARLOS MEDEIROS MIRANDA
# 907   Relatório Financeiro                                MARCELA PREST
# 972   Relatório Financeiro               ROBERTO LUIS DA SILVA TOURINHO
# 3805  Relatório Financeiro                      CARLOS MEDEIROS MIRANDA
# 3806  Relatório Financeiro                      CARLOS MEDEIROS MIRANDA
# 4410  Relatório Financeiro         JOSE DE ARIMATEIA CORIOLANO DE PAIVA
# 4413  Relatório Financeiro         JOSE DE ARIMATEIA CORIOLANO DE PAIVA
# 4414  Relatório Financeiro         JOSE DE ARIMATEIA CORIOLANO DE PAIVA
# 4415  Relatório Financeiro         JOSE DE ARIMATEIA CORIOLANO DE PAIVA
# 4416  Relatório Financeiro         JOSE DE ARIMATEIA CORIOLANO DE PAIVA
# 4713  Relatório Financeiro               JOSE CERQUEIRA DE SANTANA NETO
#
#       NR_CPF_CANDIDATO  NR_CPF_VICE_CANDIDATO  DS_CARGO  NR_PARTIDO  \
# 39         12709994780             2099711500  Prefeito          50
# 398         2159737550            90783603568  Prefeito          17
# 401         2159737550            90783603568  Prefeito          17
# 556        38247186500            63674815591  Prefeito          13
# 584        33188882572            32927193568  Prefeito          40
# 706        70580960587            88437604591  Prefeito          30
# 707        70580960587            88437604591  Prefeito          30
# 708        70580960587            88437604591  Prefeito          30
# 907        12709994780             2099711500  Prefeito          50
# 972        33188882572            32927193568  Prefeito          40
# 3805       70580960587            88437604591  Prefeito          30
# 3806       70580960587            88437604591  Prefeito          30
# 4410       29305292453            98721569568  Prefeito          10
# 4413       29305292453            98721569568  Prefeito          10
# 4414       29305292453            98721569568  Prefeito          10
# 4415       29305292453            98721569568  Prefeito          10
# 4416       29305292453            98721569568  Prefeito          10
# 4713       38247186500            63674815591  Prefeito          13
#
#         SG_PARTIDO                      NM_PARTIDO  CD_FONTE_RECEITA  \
# 39            PSOL  Partido Socialismo e Liberdade                 1
# 398            PSL          Partido Social Liberal                 2
# 401            PSL          Partido Social Liberal                 0
# 556             PT       Partido dos Trabalhadores                 2
# 584            PSB   Partido Socialista Brasileiro                 2
# 706           NOVO                    Partido Novo                 1
# 707           NOVO                    Partido Novo                 1
# 708           NOVO                    Partido Novo                 1
# 907           PSOL  Partido Socialismo e Liberdade                 1
# 972            PSB   Partido Socialista Brasileiro                 1
# 3805          NOVO                    Partido Novo                 1
# 3806          NOVO                    Partido Novo                 1
# 4410  REPUBLICANOS                    REPUBLICANOS                 1
# 4413  REPUBLICANOS                    REPUBLICANOS                 1
# 4414  REPUBLICANOS                    REPUBLICANOS                 1
# 4415  REPUBLICANOS                    REPUBLICANOS                 1
# 4416  REPUBLICANOS                    REPUBLICANOS                 1
# 4713            PT       Partido dos Trabalhadores                 1
#
#       DS_FONTE_RECEITA  ...  DS_CARGO_CANDIDATO_DOADOR NR_PARTIDO_DOADOR  \
# 39     Outros Recursos  ...                     #NULO#                -1
# 398     Fundo Especial  ...                     #NULO#                17
# 401   Fundo Partidario  ...                     #NULO#                17
# 556     Fundo Especial  ...                     #NULO#                13
# 584     Fundo Especial  ...                     #NULO#                40
# 706    Outros Recursos  ...                     #NULO#                -1
# 707    Outros Recursos  ...                     #NULO#                -1
# 708    Outros Recursos  ...                     #NULO#                -1
# 907    Outros Recursos  ...                     #NULO#                -1
# 972    Outros Recursos  ...                     #NULO#                -1
# 3805   Outros Recursos  ...                   Prefeito                30
# 3806   Outros Recursos  ...                   Prefeito                30
# 4410   Outros Recursos  ...                   Prefeito                10
# 4413   Outros Recursos  ...                   Prefeito                10
# 4414   Outros Recursos  ...                   Prefeito                10
# 4415   Outros Recursos  ...                   Prefeito                10
# 4416   Outros Recursos  ...                   Prefeito                10
# 4713   Outros Recursos  ...                   Prefeito                13
#
#       SG_PARTIDO_DOADOR              NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 39               #NULO#                         #NULO#                 #NULO#
# 398                 PSL         Partido Social Liberal  000171135157BA000001E
# 401                 PSL         Partido Social Liberal                 #NULO#
# 556                  PT      Partido dos Trabalhadores  000131135157BA000002E
# 584                 PSB  Partido Socialista Brasileiro  000401135157BA000002E
# 706              #NULO#                         #NULO#  000301135157BA000001E
# 707              #NULO#                         #NULO#                 #NULO#
# 708              #NULO#                         #NULO#                 #NULO#
# 907              #NULO#                         #NULO#  000501135157BA000001E
# 972              #NULO#                         #NULO#  000401135157BA000001E
# 3805               NOVO                   Partido Novo                 #NULO#
# 3806               NOVO                   Partido Novo                 #NULO#
# 4410       REPUBLICANOS                   REPUBLICANOS                 #NULO#
# 4413       REPUBLICANOS                   REPUBLICANOS                 #NULO#
# 4414       REPUBLICANOS                   REPUBLICANOS                 #NULO#
# 4415       REPUBLICANOS                   REPUBLICANOS                 #NULO#
# 4416       REPUBLICANOS                   REPUBLICANOS                 #NULO#
# 4713                 PT      Partido dos Trabalhadores  000131135157BA000001E
#
#      NR_DOCUMENTO_DOACAO  SQ_RECEITA  DT_RECEITA  DS_RECEITA VR_RECEITA
# 39             652687107    12757113  09/10/2020      #NULO#     370,00
# 398     9105DCD365D00E7E    12657174  08/10/2020      #NULO#  390000,00
# 401      613886000037246    12657173  02/10/2020      #NULO#   15000,00
# 556                 0001    12675636  08/10/2020      #NULO#  369989,50
# 584      613886000037344    12693268  13/10/2020      #NULO#    5000,00
# 706            591912349    12613657  29/09/2020      #NULO#    5000,00
# 707      604881000045236    12613661  07/10/2020      #NULO#    5000,00
# 708      524765000088094    12613660  02/10/2020      #NULO#   11560,00
# 907              8162230    12757112  08/10/2020      #NULO#     100,00
# 972          68702949504    12693267  07/10/2020      #NULO#     150,00
# 3805         88437604591    12613659  01/10/2020      #NULO#   11560,00
# 3806             4151874    12613658  02/10/2020      #NULO#    8000,00
# 4410               00468    12671513  08/10/2020      #NULO#    1050,00
# 4413               00473    12671514  08/10/2020      #NULO#    1050,00
# 4414               00461    12671512  08/10/2020      #NULO#    1050,00
# 4415               00479    12671516  08/10/2020      #NULO#     800,00
# 4416               00476    12671515  08/10/2020      #NULO#    1050,00
# 4713                0001    12675635  01/10/2020      #NULO#   50000,00
#
# [18 rows x 39 columns]

# %%
# quem já recebeu mais doações?

mayor_df["VR_RECEITA"].replace(".", "", inplace=True)

mayor_df["VR_RECEITA"]
#mayor_df.groupby(["NM_CANDIDATO"])["VR_RECEITA"].sum()
# Out:
# /mnt/c/Users/Ana Paula Gomes/workspace/analises/venv/lib/python3.8/site-packages/pandas/core/series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# 39         370,00
# 398     390000,00
# 401      15000,00
# 556     369989,50
# 584       5000,00
# 706       5000,00
# 707       5000,00
# 708      11560,00
# 907        100,00
# 972        150,00
# 3805     11560,00
# 3806      8000,00
# 4410      1050,00
# 4413      1050,00
# 4414      1050,00
# 4415       800,00
# 4416      1050,00
# 4713     50000,00
# Name: VR_RECEITA, dtype: object
